# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# %cd ./Revisiting-Reverse-Distillation
# !pip install geomloss
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Revisiting-Reverse-Distillation
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %% [markdown]
# # **Training**

# %%
# !python main.py --save_folder RD++ --classes leather --model_type resnet18 --batch_size 90
# Out:
# Training with classes:  ['leather']
# leather
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9341, Pixel Auroc:0.9833, Pixel Aupro: 0.9406
#  10% 1/10 [01:45<15:53, 105.99s/it]Epoch 2, Sample Auroc: 0.9929, Pixel Auroc:0.9925, Pixel Aupro: 0.9818
#  20% 2/10 [02:53<11:06, 83.26s/it] Epoch 3, Sample Auroc: 0.9956, Pixel Auroc:0.9935, Pixel Aupro: 0.9857
#  30% 3/10 [03:57<08:41, 74.44s/it]Epoch 4, Sample Auroc: 0.9963, Pixel Auroc:0.9919, Pixel Aupro: 0.9847
#  40% 4/10 [04:59<06:56, 69.46s/it]Epoch 5, Sample Auroc: 0.9959, Pixel Auroc:0.9906, Pixel Aupro: 0.9861
#  50% 5/10 [06:04<05:40, 68.08s/it]Epoch 6, Sample Auroc: 0.9997, Pixel Auroc:0.9892, Pixel Aupro: 0.9867
#  60% 6/10 [07:09<04:28, 67.09s/it]Epoch 7, Sample Auroc: 0.9993, Pixel Auroc:0.9895, Pixel Aupro: 0.9869
#  70% 7/10 [08:14<03:18, 66.22s/it]Epoch 8, Sample Auroc: 0.9997, Pixel Auroc:0.9896, Pixel Aupro: 0.9875
# ...

# %%
# !python main.py --save_folder RD++ --classes leather --model_type resnet34 --batch_size 80
# Out:
# Training with classes:  ['leather']
# leather
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 532MB/s]
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9494, Pixel Auroc:0.9422, Pixel Aupro: 0.9060
#  10% 1/10 [05:49<52:21, 349.07s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9747, Pixel Aupro: 0.9512
#  20% 2/10 [06:57<24:29, 183.75s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9753, Pixel Aupro: 0.9735
#  30% 3/10 [08:03<15:10, 130.06s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9856, Pixel Aupro: 0.9838
#  40% 4/10 [09:10<10:30, 105.07s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9879, Pixel Aupro: 0.9869
#  50% 5/10 [10:17<07:37, 91.57s/it] Epoch 6, Sample Auroc: 0.9990, Pixel Auroc:0.9878, Pixel Aupro: 0.9872
# ...

# %%
# !python main.py --save_folder RD++ --classes leather --model_type resnet50 --batch_size 20
# Out:
# Training with classes:  ['leather']
# leather
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9986, Pixel Auroc:0.9877, Pixel Aupro: 0.9787
#  10% 1/10 [01:35<14:23, 95.99s/it]Epoch 2, Sample Auroc: 0.9993, Pixel Auroc:0.9916, Pixel Aupro: 0.9895
#  20% 2/10 [03:08<12:32, 94.12s/it]Epoch 3, Sample Auroc: 0.9986, Pixel Auroc:0.9918, Pixel Aupro: 0.9897
#  30% 3/10 [04:43<10:59, 94.21s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9922, Pixel Aupro: 0.9897
#  40% 4/10 [06:15<09:20, 93.36s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9923, Pixel Aupro: 0.9897
#  50% 5/10 [07:50<07:51, 94.22s/it]Epoch 6, Sample Auroc: 1.0000, Pixel Auroc:0.9924, Pixel Aupro: 0.9897
#  60% 6/10 [09:20<06:10, 92.54s/it]Epoch 7, Sample Auroc: 1.0000, Pixel Auroc:0.9925, Pixel Aupro: 0.9895
#  70% 7/10 [10:49<04:34, 91.52s/it]Epoch 8, Sample Auroc: 1.0000, Pixel Auroc:0.9925, Pixel Aupro: 0.9896
# ...

# %%
# !python main.py --save_folder RD++ --classes leather --model_type wide_resnet50_2
# Out:
# Training with classes:  ['leather']
# leather
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /root/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
# 100% 132M/132M [00:04<00:00, 33.6MB/s]
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9997, Pixel Auroc:0.9922, Pixel Aupro: 0.9897
#  10% 1/10 [03:18<29:42, 198.04s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9940, Pixel Aupro: 0.9917
#  20% 2/10 [04:56<18:33, 139.24s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9940, Pixel Aupro: 0.9920
#  30% 3/10 [06:35<14:07, 121.13s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9940, Pixel Aupro: 0.9917
#  40% 4/10 [08:11<11:06, 111.15s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9943, Pixel Aupro: 0.9920
#  50% 5/10 [09:49<08:52, 106.48s/it]Epoch 6, Sample Auroc: 1.0000, Pixel Auroc:0.9943, Pixel Aupro: 0.9918
# ...

# %%
# !python main.py --save_folder RD++ --classes carpet --model_type resnet18 --batch_size 90
# Out:
# Training with classes:  ['carpet']
# carpet
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 160MB/s]
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.8138, Pixel Auroc:0.9088, Pixel Aupro: 0.8130
#  10% 1/10 [02:30<22:35, 150.64s/it]Epoch 2, Sample Auroc: 0.9410, Pixel Auroc:0.9389, Pixel Aupro: 0.8723
#  20% 2/10 [03:37<13:31, 101.46s/it]Epoch 3, Sample Auroc: 0.9735, Pixel Auroc:0.9616, Pixel Aupro: 0.9057
#  30% 3/10 [04:41<09:50, 84.38s/it] Epoch 4, Sample Auroc: 0.9852, Pixel Auroc:0.9714, Pixel Aupro: 0.9250
#  40% 4/10 [05:48<07:45, 77.55s/it]Epoch 5, Sample Auroc: 0.9839, Pixel Auroc:0.9748, Pixel Aupro: 0.9290
#  50% 5/10 [06:52<06:03, 72.60s/it]Epoch 6, Sample Auroc: 0.9912, Pixel Auroc:0.9788, Pixel Aupro: 0.9413
# ...

# %%
# !python main.py --save_folder RD++ --classes carpet --model_type resnet34 --batch_size 80
# Out:
# Training with classes:  ['carpet']
# carpet
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 190MB/s]
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9250, Pixel Auroc:0.9171, Pixel Aupro: 0.7033
#  10% 1/10 [01:08<10:14, 68.28s/it]Epoch 2, Sample Auroc: 0.9679, Pixel Auroc:0.9500, Pixel Aupro: 0.8074
#  20% 2/10 [02:17<09:11, 68.91s/it]Epoch 3, Sample Auroc: 0.9843, Pixel Auroc:0.9752, Pixel Aupro: 0.9147
#  30% 3/10 [03:26<08:01, 68.84s/it]Epoch 4, Sample Auroc: 0.9896, Pixel Auroc:0.9820, Pixel Aupro: 0.9519
#  40% 4/10 [04:35<06:54, 69.13s/it]Epoch 5, Sample Auroc: 0.9976, Pixel Auroc:0.9857, Pixel Aupro: 0.9643
#  50% 5/10 [05:42<05:40, 68.14s/it]Epoch 6, Sample Auroc: 0.9996, Pixel Auroc:0.9877, Pixel Aupro: 0.9693
# ...

# %%
# !python main.py --save_folder RD++ --classes carpet --model_type resnet50 --batch_size 20
# Out:
# Training with classes:  ['carpet']
# carpet
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 180MB/s]
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9117, Pixel Auroc:0.9709, Pixel Aupro: 0.9022
#  10% 1/10 [01:35<14:20, 95.57s/it]Epoch 2, Sample Auroc: 0.9731, Pixel Auroc:0.9855, Pixel Aupro: 0.9594
#  20% 2/10 [03:11<12:45, 95.63s/it]Epoch 3, Sample Auroc: 0.9819, Pixel Auroc:0.9880, Pixel Aupro: 0.9653
#  30% 3/10 [04:45<11:04, 94.94s/it]Epoch 4, Sample Auroc: 0.9852, Pixel Auroc:0.9895, Pixel Aupro: 0.9694
#  40% 4/10 [06:20<09:28, 94.83s/it]Epoch 5, Sample Auroc: 0.9835, Pixel Auroc:0.9895, Pixel Aupro: 0.9698
#  50% 5/10 [07:52<07:50, 94.00s/it]Epoch 6, Sample Auroc: 0.9884, Pixel Auroc:0.9898, Pixel Aupro: 0.9705
# ...

# %%
# !python main.py --save_folder RD++ --classes carpet --model_type wide_resnet50_2
# Out:
# Training with classes:  ['carpet']
# carpet
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9811, Pixel Auroc:0.9861, Pixel Aupro: 0.9591
#  10% 1/10 [01:47<16:11, 107.91s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9915, Pixel Aupro: 0.9755
#  20% 2/10 [03:38<14:34, 109.34s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9917, Pixel Aupro: 0.9763
#  30% 3/10 [05:24<12:34, 107.72s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9919, Pixel Aupro: 0.9764
#  40% 4/10 [07:11<10:46, 107.73s/it]Epoch 5, Sample Auroc: 0.9992, Pixel Auroc:0.9919, Pixel Aupro: 0.9769
#  50% 5/10 [08:58<08:57, 107.46s/it]Epoch 6, Sample Auroc: 0.9996, Pixel Auroc:0.9921, Pixel Aupro: 0.9772
#  60% 6/10 [10:44<07:07, 106.96s/it]Epoch 7, Sample Auroc: 0.9984, Pixel Auroc:0.9919, Pixel Aupro: 0.9770
#  70% 7/10 [12:30<05:19, 106.49s/it]Epoch 8, Sample Auroc: 0.9988, Pixel Auroc:0.9920, Pixel Aupro: 0.9773
# ...

# %%
# !python main.py --save_folder RD++ --classes leather --model_type wide_resnet101_2 --batch_size 8
# Out:
# Training with classes:  ['leather']
# leather
# with class leather, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9997, Pixel Auroc:0.9942, Pixel Aupro: 0.9921
#  10% 1/10 [05:34<50:11, 334.58s/it]Epoch 2, Sample Auroc: 0.9997, Pixel Auroc:0.9943, Pixel Aupro: 0.9921
#  20% 2/10 [07:53<29:14, 219.35s/it]Epoch 3, Sample Auroc: 0.9997, Pixel Auroc:0.9945, Pixel Aupro: 0.9923
#  30% 3/10 [10:14<21:25, 183.69s/it]Epoch 4, Sample Auroc: 0.9997, Pixel Auroc:0.9945, Pixel Aupro: 0.9922
#  40% 4/10 [12:35<16:40, 166.82s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9945, Pixel Aupro: 0.9922
#  50% 5/10 [14:59<13:13, 158.60s/it]Epoch 6, Sample Auroc: 1.0000, Pixel Auroc:0.9945, Pixel Aupro: 0.9923
#  60% 6/10 [17:21<10:11, 152.95s/it]Epoch 7, Sample Auroc: 1.0000, Pixel Auroc:0.9946, Pixel Aupro: 0.9922
#  70% 7/10 [19:45<07:30, 150.10s/it]Epoch 8, Sample Auroc: 1.0000, Pixel Auroc:0.9946, Pixel Aupro: 0.9922
# ...

# %%
# !python main.py --save_folder RD++ --classes carpet --model_type wide_resnet101_2 --batch_size 8
# Out:
# Training with classes:  ['carpet']
# carpet
# with class carpet, Training with 10 Epoch
#   0% 0/10 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9928, Pixel Auroc:0.9903, Pixel Aupro: 0.9731
#  10% 1/10 [02:50<25:38, 170.97s/it]Epoch 2, Sample Auroc: 0.9948, Pixel Auroc:0.9909, Pixel Aupro: 0.9749
#  20% 2/10 [05:22<21:18, 159.75s/it]Epoch 3, Sample Auroc: 0.9948, Pixel Auroc:0.9915, Pixel Aupro: 0.9758
#  30% 3/10 [07:52<18:05, 155.00s/it]Epoch 4, Sample Auroc: 0.9960, Pixel Auroc:0.9915, Pixel Aupro: 0.9758
#  40% 4/10 [10:23<15:20, 153.40s/it]Epoch 5, Sample Auroc: 0.9964, Pixel Auroc:0.9916, Pixel Aupro: 0.9762
#  50% 5/10 [12:59<12:51, 154.28s/it]Epoch 6, Sample Auroc: 0.9968, Pixel Auroc:0.9917, Pixel Aupro: 0.9759
#  60% 6/10 [15:31<10:14, 153.75s/it]Epoch 7, Sample Auroc: 0.9948, Pixel Auroc:0.9917, Pixel Aupro: 0.9761
#  70% 7/10 [18:00<07:36, 152.25s/it]Epoch 8, Sample Auroc: 0.9952, Pixel Auroc:0.9916, Pixel Aupro: 0.9759
# ...

# %% [markdown]
# # **Inferences**

# %%
# !python inference.py --checkpoint_folder RD++ --classes carpet --model_type resnet18
# Out:
# Lenght of list sp:  117
# Mean inference time (ms):  19.48195726495726
# 0:00:10.075263
# carpet: Sample Auroc: 0.9956, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes leather --model_type resnet18
# Out:
# Lenght of list sp:  124
# Mean inference time (ms):  19.271499999999993
# 0:02:17.186503
# leather: Sample Auroc: 0.9993, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes carpet --model_type resnet34
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 258MB/s]
# Lenght of list sp:  117
# Mean inference time (ms):  25.72879487179487
# 0:00:11.193130
# carpet: Sample Auroc: 0.9988, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes leather --model_type resnet34
# Out:
# Lenght of list sp:  124
# Mean inference time (ms):  26.098774193548394
# 0:00:11.503421
# leather: Sample Auroc: 0.9990, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes carpet --model_type resnet50
# Out:
# Lenght of list sp:  117
# Mean inference time (ms):  41.373888888888885
# 0:00:12.659731
# carpet: Sample Auroc: 0.9884, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes leather --model_type resnet50
# Out:
# Lenght of list sp:  124
# Mean inference time (ms):  39.427467741935494
# 0:00:12.467807
# leather: Sample Auroc: 1.0000, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes carpet --model_type wide_resnet50_2
# Out:
# Lenght of list sp:  117
# Mean inference time (ms):  45.90870085470083
# 0:00:12.939435
# carpet: Sample Auroc: 0.9996, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes leather --model_type wide_resnet50_2
# Out:
# Lenght of list sp:  124
# Mean inference time (ms):  43.31790322580647
# 0:00:12.993647
# leather: Sample Auroc: 1.0000, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes carpet --model_type wide_resnet101_2
# Out:
# Lenght of list sp:  117
# Mean inference time (ms) :  51.66041025641024
# 0:00:14.100823
# carpet: Sample Auroc: 0.9968, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python inference.py --checkpoint_folder RD++ --classes leather --model_type wide_resnet101_2
# Out:
# Lenght of list sp:  124
# Mean inference time (ms) :  49.71158870967743
# 0:00:13.865252
# leather: Sample Auroc: 1.0000, Pixel Auroc:0.0000, Pixel Aupro: 0.0000

# %%
# !python main.py --save_folder RD++ --classes leather --model_type resnet34 --batch_size 80
# Out:
# Training with classes:  ['leather']
# leather
# with class leather, Training with 40 Epoch
#   0% 0/40 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.9494, Pixel Auroc:0.9422, Pixel Aupro: 0.9060
#   2% 1/40 [01:05<42:37, 65.58s/it]Epoch 2, Sample Auroc: 1.0000, Pixel Auroc:0.9747, Pixel Aupro: 0.9512
#   5% 2/40 [02:11<41:33, 65.61s/it]Epoch 3, Sample Auroc: 1.0000, Pixel Auroc:0.9753, Pixel Aupro: 0.9735
#   8% 3/40 [03:15<39:57, 64.80s/it]Epoch 4, Sample Auroc: 1.0000, Pixel Auroc:0.9856, Pixel Aupro: 0.9838
#  10% 4/40 [04:17<38:24, 64.01s/it]Epoch 5, Sample Auroc: 1.0000, Pixel Auroc:0.9879, Pixel Aupro: 0.9869
#  12% 5/40 [05:22<37:22, 64.09s/it]Epoch 6, Sample Auroc: 0.9990, Pixel Auroc:0.9878, Pixel Aupro: 0.9872
#  15% 6/40 [06:24<35:59, 63.53s/it]Epoch 7, Sample Auroc: 0.9990, Pixel Auroc:0.9885, Pixel Aupro: 0.9882
#  18% 7/40 [07:29<35:08, 63.88s/it]Epoch 8, Sample Auroc: 0.9986, Pixel Auroc:0.9889, Pixel Aupro: 0.9887
# ...

# %%
# !python main.py --save_folder RD++ --classes Class02 --model_type resnet34 --batch_size 80
# Out:
# Training with classes:  ['Class02']
# Class02
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 304MB/s]
# with class Class02, Training with 100 Epoch
#   0% 0/100 [00:00<?, ?it/s]Epoch 1, Sample Auroc: 0.4998, Pixel Auroc:0.6667, Pixel Aupro: 0.2137
#   1% 1/100 [09:37<15:53:08, 577.67s/it]Epoch 2, Sample Auroc: 0.6055, Pixel Auroc:0.7365, Pixel Aupro: 0.2627
#   2% 2/100 [11:33<8:19:43, 305.95s/it] Epoch 3, Sample Auroc: 0.7568, Pixel Auroc:0.9072, Pixel Aupro: 0.3688
#   3% 3/100 [13:25<5:51:42, 217.55s/it]Epoch 4, Sample Auroc: 0.7931, Pixel Auroc:0.9534, Pixel Aupro: 0.4693
#   4% 4/100 [15:20<4:43:23, 177.12s/it]Epoch 5, Sample Auroc: 0.8449, Pixel Auroc:0.9613, Pixel Aupro: 0.5460
#   5% 5/100 [17:13<4:03:48, 153.99s/it]Epoch 6, Sample Auroc: 0.8513, Pixel Auroc:0.9606, Pixel Aupro: 0.5469
# ...
